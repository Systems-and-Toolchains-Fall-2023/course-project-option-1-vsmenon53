# %% [markdown]
# # Course Project - Option 1 START

# %% [markdown]
# # Task 1

# %%
import findspark
findspark.init()
findspark.find()
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import monotonically_increasing_id
spark = SparkSession.builder.appName('fifa').getOrCreate()

# %%
file_paths = []
for year in range(15, 23):
    file_path = f"players_{year}.csv"
    file_paths.append(file_path)

# %%
from pyspark.sql.functions import *
from functools import reduce
data_frames = []

for file_path in file_paths:
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    
    # Add a new column for the year.
    year = int(file_path.split("_")[1].split(".")[0]) + 2000
    df = df.withColumn('year', lit(year))
    
    # for test
    df.show(1, vertical = True)
    
    data_frames.append(df)

merged_df = reduce(lambda x, y: x.union(y), data_frames)

merged_df.show(5, vertical = True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | CF
#  overall                     | 93
#  potential                   | 95
#  value_eur                   | 1.005E8
#  wage_eur                    | 550000.0
#  age                         | 27
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 169
#  weight_kg                   | 67
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | CF
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01 00:00:00
#  club_contract_valid_until   | 2018
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | CF
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Normal (170-)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Finesse Shot, Spe...
#  pace                        | 93
#  shooting                    | 89
#  passing                     | 86
#  dribbling                   | 96
#  defending                   | 27
#  physic                      | 63
#  attacking_crossing          | 84
#  attacking_finishing         | 94
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 89
#  attacking_volleys           | 85
#  skill_dribbling             | 96
#  skill_curve                 | 89
#  skill_fk_accuracy           | 90
#  skill_long_passing          | 76
#  skill_ball_control          | 96
#  movement_acceleration       | 96
#  movement_sprint_speed       | 90
#  movement_agility            | 94
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 80
#  power_jumping               | 73
#  power_stamina               | 77
#  power_strength              | 60
#  power_long_shots            | 88
#  mentality_aggression        | 48
#  mentality_interceptions     | 22
#  mentality_positioning       | 92
#  mentality_vision            | 90
#  mentality_penalties         | 76
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 21
#  defending_sliding_tackle    | 20
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92+3
#  lf                          | 90+3
#  cf                          | 90+3
#  rf                          | 90+3
#  rw                          | 92+3
#  lam                         | 92+3
#  cam                         | 92+3
#  ram                         | 92+3
#  lm                          | 90+3
#  lcm                         | 79+3
#  cm                          | 79+3
#  rcm                         | 79+3
#  rm                          | 90+3
#  lwb                         | 62+3
#  ldm                         | 62+3
#  cdm                         | 62+3
#  rdm                         | 62+3
#  rwb                         | 62+3
#  lb                          | 54+3
#  lcb                         | 45+3
#  cb                          | 45+3
#  rcb                         | 45+3
#  rb                          | 54+3
#  gk                          | 15+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
# only showing top 1 row
#
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, CF
#  overall                     | 94
#  potential                   | 95
#  value_eur                   | 1.11E8
#  wage_eur                    | 550000.0
#  age                         | 28
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | RW
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01 00:00:00
#  club_contract_valid_until   | 2018
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | RW
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Finesse Shot, Spe...
#  pace                        | 92
#  shooting                    | 88
#  passing                     | 86
#  dribbling                   | 95
#  defending                   | 24
#  physic                      | 62
#  attacking_crossing          | 80
#  attacking_finishing         | 93
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 88
#  attacking_volleys           | 85
#  skill_dribbling             | 96
#  skill_curve                 | 89
#  skill_fk_accuracy           | 90
#  skill_long_passing          | 79
#  skill_ball_control          | 96
#  movement_acceleration       | 95
#  movement_sprint_speed       | 90
#  movement_agility            | 92
#  movement_reactions          | 92
#  movement_balance            | 95
#  power_shot_power            | 80
#  power_jumping               | 68
#  power_stamina               | 76
#  power_strength              | 59
#  power_long_shots            | 88
#  mentality_aggression        | 48
#  mentality_interceptions     | 22
#  mentality_positioning       | 90
#  mentality_vision            | 90
#  mentality_penalties         | 74
#  mentality_composure         | null
#  defending_marking_awareness | 13
#  defending_standing_tackle   | 23
#  defending_sliding_tackle    | 21
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 87+3
#  st                          | 87+3
#  rs                          | 87+3
#  lw                          | 91+3
#  lf                          | 91+3
#  cf                          | 91+3
#  rf                          | 91+3
#  rw                          | 91+3
#  lam                         | 91+3
#  cam                         | 91+3
#  ram                         | 91+3
#  lm                          | 90+3
#  lcm                         | 82+3
#  cm                          | 82+3
#  rcm                         | 82+3
#  rm                          | 90+3
#  lwb                         | 62+3
#  ldm                         | 57+3
#  cdm                         | 57+3
#  rdm                         | 57+3
#  rwb                         | 62+3
#  lb                          | 57+3
#  lcb                         | 44+3
#  cb                          | 44+3
#  rcb                         | 44+3
#  rb                          | 57+3
#  gk                          | 19+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2016
# only showing top 1 row
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 20801
#  player_url                  | https://sofifa.co...
#  short_name                  | Cristiano Ronaldo
#  long_name                   | Cristiano Ronaldo...
#  player_positions            | LW, LM, ST
#  overall                     | 94
#  potential                   | 94
#  value_eur                   | 8.7E7
#  wage_eur                    | 575000.0
#  age                         | 31
#  dob                         | 1985-02-05 00:00:00
#  height_cm                   | 185
#  weight_kg                   | 80
#  club_team_id                | 243.0
#  club_name                   | Real Madrid CF
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | LW
#  club_jersey_number          | 7
#  club_loaned_from            | null
#  club_joined                 | 2009-07-01 00:00:00
#  club_contract_valid_until   | 2018
#  nationality_id              | 38
#  nationality_name            | Portugal
#  nation_team_id              | 1354.0
#  nation_position             | LS
#  nation_jersey_number        | 7
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 5
#  international_reputation    | 5
#  work_rate                   | High/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 92
#  shooting                    | 92
#  passing                     | 81
#  dribbling                   | 91
#  defending                   | 33
#  physic                      | 80
#  attacking_crossing          | 84
#  attacking_finishing         | 93
#  attacking_heading_accuracy  | 87
#  attacking_short_passing     | 82
#  attacking_volleys           | 88
#  skill_dribbling             | 93
#  skill_curve                 | 81
#  skill_fk_accuracy           | 77
#  skill_long_passing          | 72
#  skill_ball_control          | 92
#  movement_acceleration       | 91
#  movement_sprint_speed       | 92
#  movement_agility            | 90
#  movement_reactions          | 96
#  movement_balance            | 63
#  power_shot_power            | 94
#  power_jumping               | 95
#  power_stamina               | 92
#  power_strength              | 80
#  power_long_shots            | 92
#  mentality_aggression        | 63
#  mentality_interceptions     | 29
#  mentality_positioning       | 94
#  mentality_vision            | 85
#  mentality_penalties         | 85
#  mentality_composure         | 86
#  defending_marking_awareness | 22
#  defending_standing_tackle   | 31
#  defending_sliding_tackle    | 23
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 11
#  goalkeeping_speed           | null
#  ls                          | 91+3
#  st                          | 91+3
#  rs                          | 91+3
#  lw                          | 91+3
#  lf                          | 91+3
#  cf                          | 91+3
#  rf                          | 91+3
#  rw                          | 91+3
#  lam                         | 89+4
#  cam                         | 89+4
#  ram                         | 89+4
#  lm                          | 89+4
#  lcm                         | 81+4
#  cm                          | 81+4
#  rcm                         | 81+4
#  rm                          | 89+4
#  lwb                         | 65+4
#  ldm                         | 61+4
#  cdm                         | 61+4
#  rdm                         | 61+4
#  rwb                         | 65+4
#  lb                          | 61+4
#  lcb                         | 53+4
#  cb                          | 53+4
#  rcb                         | 53+4
#  rb                          | 61+4
#  gk                          | 20+4
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2017
# only showing top 1 row
#
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 20801
#  player_url                  | https://sofifa.co...
#  short_name                  | Cristiano Ronaldo
#  long_name                   | Cristiano Ronaldo...
#  player_positions            | LW, ST
#  overall                     | 94
#  potential                   | 94
#  value_eur                   | 9.55E7
#  wage_eur                    | 575000.0
#  age                         | 32
#  dob                         | 1985-02-05 00:00:00
#  height_cm                   | 185
#  weight_kg                   | 80
#  club_team_id                | 243.0
#  club_name                   | Real Madrid CF
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | LW
#  club_jersey_number          | 7
#  club_loaned_from            | null
#  club_joined                 | 2009-07-01 00:00:00
#  club_contract_valid_until   | 2021
#  nationality_id              | 38
#  nationality_name            | Portugal
#  nation_team_id              | 1354.0
#  nation_position             | LS
#  nation_jersey_number        | 7
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 5
#  international_reputation    | 5
#  work_rate                   | High/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 195800000
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 90
#  shooting                    | 93
#  passing                     | 82
#  dribbling                   | 90
#  defending                   | 33
#  physic                      | 80
#  attacking_crossing          | 85
#  attacking_finishing         | 94
#  attacking_heading_accuracy  | 88
#  attacking_short_passing     | 83
#  attacking_volleys           | 88
#  skill_dribbling             | 91
#  skill_curve                 | 81
#  skill_fk_accuracy           | 76
#  skill_long_passing          | 77
#  skill_ball_control          | 93
#  movement_acceleration       | 89
#  movement_sprint_speed       | 91
#  movement_agility            | 89
#  movement_reactions          | 96
#  movement_balance            | 63
#  power_shot_power            | 94
#  power_jumping               | 95
#  power_stamina               | 92
#  power_strength              | 80
#  power_long_shots            | 92
#  mentality_aggression        | 63
#  mentality_interceptions     | 29
#  mentality_positioning       | 95
#  mentality_vision            | 85
#  mentality_penalties         | 85
#  mentality_composure         | 95
#  defending_marking_awareness | 22
#  defending_standing_tackle   | 31
#  defending_sliding_tackle    | 23
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 11
#  goalkeeping_speed           | null
#  ls                          | 92+2
#  st                          | 92+2
#  rs                          | 92+2
#  lw                          | 91+3
#  lf                          | 91+3
#  cf                          | 91+3
#  rf                          | 91+3
#  rw                          | 91+3
#  lam                         | 89+4
#  cam                         | 89+4
#  ram                         | 89+4
#  lm                          | 89+4
#  lcm                         | 82+4
#  cm                          | 82+4
#  rcm                         | 82+4
#  rm                          | 89+4
#  lwb                         | 66+4
#  ldm                         | 62+4
#  cdm                         | 62+4
#  rdm                         | 62+4
#  rwb                         | 66+4
#  lb                          | 61+4
#  lcb                         | 53+4
#  cb                          | 53+4
#  rcb                         | 53+4
#  rb                          | 61+4
#  gk                          | 20+4
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2018
# only showing top 1 row
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 20801
#  player_url                  | https://sofifa.co...
#  short_name                  | Cristiano Ronaldo
#  long_name                   | Cristiano Ronaldo...
#  player_positions            | ST, LW
#  overall                     | 94
#  potential                   | 94
#  value_eur                   | 7.7E7
#  wage_eur                    | 400000.0
#  age                         | 33
#  dob                         | 1985-02-05 00:00:00
#  height_cm                   | 187
#  weight_kg                   | 83
#  club_team_id                | 45.0
#  club_name                   | Juventus
#  league_name                 | Italian Serie A
#  league_level                | 1
#  club_position               | ST
#  club_jersey_number          | 7
#  club_loaned_from            | null
#  club_joined                 | 2018-07-10 00:00:00
#  club_contract_valid_until   | 2022
#  nationality_id              | 38
#  nationality_name            | Portugal
#  nation_team_id              | 1354.0
#  nation_position             | LS
#  nation_jersey_number        | 7
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 5
#  international_reputation    | 5
#  work_rate                   | High/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 127100000
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 90
#  shooting                    | 93
#  passing                     | 81
#  dribbling                   | 89
#  defending                   | 35
#  physic                      | 79
#  attacking_crossing          | 84
#  attacking_finishing         | 94
#  attacking_heading_accuracy  | 89
#  attacking_short_passing     | 81
#  attacking_volleys           | 87
#  skill_dribbling             | 88
#  skill_curve                 | 81
#  skill_fk_accuracy           | 76
#  skill_long_passing          | 77
#  skill_ball_control          | 94
#  movement_acceleration       | 89
#  movement_sprint_speed       | 91
#  movement_agility            | 87
#  movement_reactions          | 96
#  movement_balance            | 70
#  power_shot_power            | 95
#  power_jumping               | 95
#  power_stamina               | 88
#  power_strength              | 79
#  power_long_shots            | 93
#  mentality_aggression        | 63
#  mentality_interceptions     | 29
#  mentality_positioning       | 95
#  mentality_vision            | 82
#  mentality_penalties         | 85
#  mentality_composure         | 95
#  defending_marking_awareness | 28
#  defending_standing_tackle   | 31
#  defending_sliding_tackle    | 23
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 11
#  goalkeeping_speed           | null
#  ls                          | 92+2
#  st                          | 92+2
#  rs                          | 92+2
#  lw                          | 90
#  lf                          | 91
#  cf                          | 91
#  rf                          | 91
#  rw                          | 90
#  lam                         | 88+4
#  cam                         | 88+4
#  ram                         | 88+4
#  lm                          | 88+4
#  lcm                         | 81+4
#  cm                          | 81+4
#  rcm                         | 81+4
#  rm                          | 88+4
#  lwb                         | 65+4
#  ldm                         | 61+4
#  cdm                         | 61+4
#  rdm                         | 61+4
#  rwb                         | 65+4
#  lb                          | 61+4
#  lcb                         | 54+4
#  cb                          | 54+4
#  rcb                         | 54+4
#  rb                          | 61+4
#  gk                          | 20+4
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2019
# only showing top 1 row
#
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, CF, ST
#  overall                     | 94
#  potential                   | 94
#  value_eur                   | 9.55E7
#  wage_eur                    | 560000.0
#  age                         | 32
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | RW
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01 00:00:00
#  club_contract_valid_until   | 2021
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | null
#  nation_position             | null
#  nation_jersey_number        | null
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 195800000
#  player_tags                 | #Dribbler, #Dista...
#  player_traits               | Finesse Shot, Lon...
#  pace                        | 87
#  shooting                    | 92
#  passing                     | 92
#  dribbling                   | 96
#  defending                   | 39
#  physic                      | 66
#  attacking_crossing          | 88
#  attacking_finishing         | 95
#  attacking_heading_accuracy  | 70
#  attacking_short_passing     | 92
#  attacking_volleys           | 88
#  skill_dribbling             | 97
#  skill_curve                 | 93
#  skill_fk_accuracy           | 94
#  skill_long_passing          | 92
#  skill_ball_control          | 96
#  movement_acceleration       | 91
#  movement_sprint_speed       | 84
#  movement_agility            | 93
#  movement_reactions          | 95
#  movement_balance            | 95
#  power_shot_power            | 86
#  power_jumping               | 68
#  power_stamina               | 75
#  power_strength              | 68
#  power_long_shots            | 94
#  mentality_aggression        | 48
#  mentality_interceptions     | 40
#  mentality_positioning       | 94
#  mentality_vision            | 94
#  mentality_penalties         | 75
#  mentality_composure         | 96
#  defending_marking_awareness | 33
#  defending_standing_tackle   | 37
#  defending_sliding_tackle    | 26
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+5
#  st                          | 89+5
#  rs                          | 89+5
#  lw                          | 93+1
#  lf                          | 93+1
#  cf                          | 93+1
#  rf                          | 93+1
#  rw                          | 93+1
#  lam                         | 94
#  cam                         | 94
#  ram                         | 94
#  lm                          | 92+2
#  lcm                         | 87+6
#  cm                          | 87+6
#  rcm                         | 87+6
#  rm                          | 92+2
#  lwb                         | 68+6
#  ldm                         | 66+6
#  cdm                         | 66+6
#  rdm                         | 66+6
#  rwb                         | 68+6
#  lb                          | 63+6
#  lcb                         | 53+6
#  cb                          | 53+6
#  rcb                         | 53+6
#  rb                          | 63+6
#  gk                          | 19+6
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | null
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2020
# only showing top 1 row
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, ST, CF
#  overall                     | 93
#  potential                   | 93
#  value_eur                   | 1.035E8
#  wage_eur                    | 560000.0
#  age                         | 33
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | CAM
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01 00:00:00
#  club_contract_valid_until   | 2021
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | RW
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 138400000
#  player_tags                 | #Dribbler, #Dista...
#  player_traits               | Finesse Shot, Lon...
#  pace                        | 85
#  shooting                    | 92
#  passing                     | 91
#  dribbling                   | 95
#  defending                   | 38
#  physic                      | 65
#  attacking_crossing          | 85
#  attacking_finishing         | 95
#  attacking_heading_accuracy  | 70
#  attacking_short_passing     | 91
#  attacking_volleys           | 88
#  skill_dribbling             | 96
#  skill_curve                 | 93
#  skill_fk_accuracy           | 94
#  skill_long_passing          | 91
#  skill_ball_control          | 96
#  movement_acceleration       | 91
#  movement_sprint_speed       | 80
#  movement_agility            | 91
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 86
#  power_jumping               | 68
#  power_stamina               | 72
#  power_strength              | 69
#  power_long_shots            | 94
#  mentality_aggression        | 44
#  mentality_interceptions     | 40
#  mentality_positioning       | 93
#  mentality_vision            | 95
#  mentality_penalties         | 75
#  mentality_composure         | 96
#  defending_marking_awareness | 32
#  defending_standing_tackle   | 35
#  defending_sliding_tackle    | 24
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92
#  lf                          | 93
#  cf                          | 93
#  rf                          | 93
#  rw                          | 92
#  lam                         | 93
#  cam                         | 93
#  ram                         | 93
#  lm                          | 91+2
#  lcm                         | 87+3
#  cm                          | 87+3
#  rcm                         | 87+3
#  rm                          | 91+2
#  lwb                         | 66+3
#  ldm                         | 65+3
#  cdm                         | 65+3
#  rdm                         | 65+3
#  rwb                         | 66+3
#  lb                          | 62+3
#  lcb                         | 52+3
#  cb                          | 52+3
#  rcb                         | 52+3
#  rb                          | 62+3
#  gk                          | 19+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2021
# only showing top 1 row
#
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, ST, CF
#  overall                     | 93
#  potential                   | 93
#  value_eur                   | 7.8E7
#  wage_eur                    | 320000.0
#  age                         | 34
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 73.0
#  club_name                   | Paris Saint-Germain
#  league_name                 | French Ligue 1
#  league_level                | 1
#  club_position               | RW
#  club_jersey_number          | 30
#  club_loaned_from            | null
#  club_joined                 | 2021-08-10 00:00:00
#  club_contract_valid_until   | 2023
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | RW
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 144300000
#  player_tags                 | #Dribbler, #Dista...
#  player_traits               | Finesse Shot, Lon...
#  pace                        | 85
#  shooting                    | 92
#  passing                     | 91
#  dribbling                   | 95
#  defending                   | 34
#  physic                      | 65
#  attacking_crossing          | 85
#  attacking_finishing         | 95
#  attacking_heading_accuracy  | 70
#  attacking_short_passing     | 91
#  attacking_volleys           | 88
#  skill_dribbling             | 96
#  skill_curve                 | 93
#  skill_fk_accuracy           | 94
#  skill_long_passing          | 91
#  skill_ball_control          | 96
#  movement_acceleration       | 91
#  movement_sprint_speed       | 80
#  movement_agility            | 91
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 86
#  power_jumping               | 68
#  power_stamina               | 72
#  power_strength              | 69
#  power_long_shots            | 94
#  mentality_aggression        | 44
#  mentality_interceptions     | 40
#  mentality_positioning       | 93
#  mentality_vision            | 95
#  mentality_penalties         | 75
#  mentality_composure         | 96
#  defending_marking_awareness | 20
#  defending_standing_tackle   | 35
#  defending_sliding_tackle    | 24
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92
#  lf                          | 93
#  cf                          | 93
#  rf                          | 93
#  rw                          | 92
#  lam                         | 93
#  cam                         | 93
#  ram                         | 93
#  lm                          | 91+2
#  lcm                         | 87+3
#  cm                          | 87+3
#  rcm                         | 87+3
#  rm                          | 91+2
#  lwb                         | 66+3
#  ldm                         | 64+3
#  cdm                         | 64+3
#  rdm                         | 64+3
#  rwb                         | 66+3
#  lb                          | 61+3
#  lcb                         | 50+3
#  cb                          | 50+3
#  rcb                         | 50+3
#  rb                          | 61+3
#  gk                          | 19+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2022
# only showing top 1 row
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | CF
# ...
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Diver, Injury Pro...
#  pace                        | 93
#  shooting                    | 86
#  passing                     | 83
#  dribbling                   | 92
#  defending                   | 32
#  physic                      | 64
#  attacking_crossing          | 80
#  attacking_finishing         | 85
#  attacking_heading_accuracy  | 50
#  attacking_short_passing     | 86
#  attacking_volleys           | 86
#  skill_dribbling             | 93
#  skill_curve                 | 85
#  skill_fk_accuracy           | 83
#  skill_long_passing          | 76
#  skill_ball_control          | 90
#  movement_acceleration       | 93
#  movement_sprint_speed       | 93
#  movement_agility            | 93
#  movement_reactions          | 89
#  movement_balance            | 91
#  power_shot_power            | 86
#  power_jumping               | 61
#  power_stamina               | 78
#  power_strength              | 65
#  power_long_shots            | 90
#  mentality_aggression        | 47
#  mentality_interceptions     | 39
#  mentality_positioning       | 89
#  mentality_vision            | 84
#  mentality_penalties         | 80
#  mentality_composure         | null
#  defending_marking_awareness | 29
#  defending_standing_tackle   | 26
#  defending_sliding_tackle    | 26
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 8
#  goalkeeping_kicking         | 11
#  goalkeeping_positioning     | 5
#  goalkeeping_reflexes        | 15
#  goalkeeping_speed           | null
#  ls                          | 84+3
#  st                          | 84+3
#  rs                          | 84+3
#  lw                          | 88+2
#  lf                          | 87+3
#  cf                          | 87+3
#  rf                          | 87+3
#  rw                          | 88+2
#  lam                         | 88+2
#  cam                         | 88+2
#  ram                         | 88+2
#  lm                          | 87+3
#  lcm                         | 78+3
#  cm                          | 78+3
#  rcm                         | 78+3
#  rm                          | 87+3
#  lwb                         | 64+3
#  ldm                         | 64+3
#  cdm                         | 64+3
#  rdm                         | 64+3
#  rwb                         | 64+3
#  lb                          | 55+3
#  lcb                         | 46+3
#  cb                          | 46+3
#  rcb                         | 46+3
#  rb                          | 55+3
#  gk                          | 14+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
# -RECORD 3-------------------------------------------
#  sofifa_id                   | 41236
#  player_url                  | https://sofifa.co...
#  short_name                  | Z. Ibrahimović
#  long_name                   | Zlatan Ibrahimović
#  player_positions            | ST
#  overall                     | 90
#  potential                   | 90
#  value_eur                   | 5.25E7
#  wage_eur                    | 275000.0
#  age                         | 32
#  dob                         | 1981-10-03 00:00:00
#  height_cm                   | 195
#  weight_kg                   | 95
#  club_team_id                | 73.0
#  club_name                   | Paris Saint-Germain
#  league_name                 | French Ligue 1
#  league_level                | 1
#  club_position               | ST
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2012-07-01 00:00:00
#  club_contract_valid_until   | 2016
#  nationality_id              | 46
#  nationality_name            | Sweden
#  nation_team_id              | 1363.0
#  nation_position             | ST
#  nation_jersey_number        | 10
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Poacher, #Aerial...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 76
#  shooting                    | 91
#  passing                     | 81
#  dribbling                   | 86
#  defending                   | 34
#  physic                      | 86
#  attacking_crossing          | 76
#  attacking_finishing         | 91
#  attacking_heading_accuracy  | 76
#  attacking_short_passing     | 84
#  attacking_volleys           | 92
#  skill_dribbling             | 88
#  skill_curve                 | 80
#  skill_fk_accuracy           | 80
#  skill_long_passing          | 76
#  skill_ball_control          | 90
#  movement_acceleration       | 74
#  movement_sprint_speed       | 77
#  movement_agility            | 86
#  movement_reactions          | 85
#  movement_balance            | 41
#  power_shot_power            | 93
#  power_jumping               | 72
#  power_stamina               | 78
#  power_strength              | 93
#  power_long_shots            | 88
#  mentality_aggression        | 84
#  mentality_interceptions     | 20
#  mentality_positioning       | 86
#  mentality_vision            | 83
#  mentality_penalties         | 91
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 41
#  defending_sliding_tackle    | 27
#  goalkeeping_diving          | 13
#  goalkeeping_handling        | 15
#  goalkeeping_kicking         | 10
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 12
#  goalkeeping_speed           | null
#  ls                          | 87+3
#  st                          | 87+3
#  rs                          | 87+3
#  lw                          | 84+3
#  lf                          | 86+3
#  cf                          | 86+3
#  rf                          | 86+3
#  rw                          | 84+3
#  lam                         | 86+3
#  cam                         | 86+3
#  ram                         | 86+3
#  lm                          | 83+3
#  lcm                         | 76+3
#  cm                          | 76+3
#  rcm                         | 76+3
#  rm                          | 83+3
#  lwb                         | 61+3
#  ldm                         | 65+3
#  cdm                         | 65+3
#  rdm                         | 65+3
#  rwb                         | 61+3
#  lb                          | 56+3
#  lcb                         | 55+3
#  cb                          | 55+3
#  rcb                         | 55+3
#  rb                          | 56+3
#  gk                          | 17+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
# -RECORD 4-------------------------------------------
#  sofifa_id                   | 167495
#  player_url                  | https://sofifa.co...
#  short_name                  | M. Neuer
#  long_name                   | Manuel Peter Neuer
#  player_positions            | GK
#  overall                     | 90
#  potential                   | 90
#  value_eur                   | 6.35E7
#  wage_eur                    | 300000.0
#  age                         | 28
#  dob                         | 1986-03-27 00:00:00
#  height_cm                   | 193
#  weight_kg                   | 92
#  club_team_id                | 21.0
#  club_name                   | FC Bayern München
#  league_name                 | German 1. Bundesliga
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 1
#  club_loaned_from            | null
#  club_joined                 | 2011-07-01 00:00:00
#  club_contract_valid_until   | 2019
#  nationality_id              | 21
#  nationality_name            | Germany
#  nation_team_id              | 1337.0
#  nation_position             | GK
#  nation_jersey_number        | 1
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 1
#  international_reputation    | 5
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | null
#  player_traits               | GK Up for Corners...
#  pace                        | null
#  shooting                    | null
#  passing                     | null
#  dribbling                   | null
#  defending                   | null
#  physic                      | null
#  attacking_crossing          | 25
#  attacking_finishing         | 25
#  attacking_heading_accuracy  | 25
#  attacking_short_passing     | 42
#  attacking_volleys           | 25
#  skill_dribbling             | 25
#  skill_curve                 | 25
#  skill_fk_accuracy           | 25
#  skill_long_passing          | 41
#  skill_ball_control          | 31
#  movement_acceleration       | 58
#  movement_sprint_speed       | 61
#  movement_agility            | 43
#  movement_reactions          | 89
#  movement_balance            | 35
#  power_shot_power            | 42
#  power_jumping               | 78
#  power_stamina               | 44
#  power_strength              | 83
#  power_long_shots            | 25
#  mentality_aggression        | 29
#  mentality_interceptions     | 30
#  mentality_positioning       | 25
#  mentality_vision            | 20
#  mentality_penalties         | 37
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 25
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 87
#  goalkeeping_handling        | 85
#  goalkeeping_kicking         | 92
#  goalkeeping_positioning     | 90
#  goalkeeping_reflexes        | 86
#  goalkeeping_speed           | 60
#  ls                          | 38+3
#  st                          | 38+3
#  rs                          | 38+3
#  lw                          | 36+3
#  lf                          | 37+3
#  cf                          | 37+3
#  rf                          | 37+3
#  rw                          | 36+3
#  lam                         | 36+3
#  cam                         | 36+3
#  ram                         | 36+3
#  lm                          | 38+3
#  lcm                         | 36+3
#  cm                          | 36+3
#  rcm                         | 36+3
#  rm                          | 38+3
#  lwb                         | 36+3
#  ldm                         | 40+3
#  cdm                         | 40+3
#  rdm                         | 40+3
#  rwb                         | 36+3
#  lb                          | 36+3
#  lcb                         | 38+3
#  cb                          | 38+3
#  rcb                         | 38+3
#  rb                          | 36+3
#  gk                          | 87+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
# only showing top 5 rows

# %%
merged_df.groupby("year").count().show()
# Out:
# +----+-----+
# |year|count|
# +----+-----+
# |2015|16155|
# |2016|15623|
# |2017|17596|
# |2018|17954|
# |2019|18085|
# |2020|18483|
# |2021|18944|
# |2022|19239|
# +----+-----+

# %%
playersdf = merged_df.withColumn("unique_id", monotonically_increasing_id())
playersdf.show(5, vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | CF
#  overall                     | 93
#  potential                   | 95
#  value_eur                   | 1.005E8
#  wage_eur                    | 550000.0
#  age                         | 27
#  dob                         | 1987-06-24 00:00:00
#  height_cm                   | 169
#  weight_kg                   | 67
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | CF
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01 00:00:00
#  club_contract_valid_until   | 2018
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | CF
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Normal (170-)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Finesse Shot, Spe...
#  pace                        | 93
#  shooting                    | 89
#  passing                     | 86
#  dribbling                   | 96
#  defending                   | 27
#  physic                      | 63
#  attacking_crossing          | 84
#  attacking_finishing         | 94
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 89
#  attacking_volleys           | 85
#  skill_dribbling             | 96
#  skill_curve                 | 89
#  skill_fk_accuracy           | 90
#  skill_long_passing          | 76
#  skill_ball_control          | 96
#  movement_acceleration       | 96
#  movement_sprint_speed       | 90
#  movement_agility            | 94
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 80
#  power_jumping               | 73
#  power_stamina               | 77
#  power_strength              | 60
#  power_long_shots            | 88
#  mentality_aggression        | 48
#  mentality_interceptions     | 22
#  mentality_positioning       | 92
#  mentality_vision            | 90
#  mentality_penalties         | 76
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 21
#  defending_sliding_tackle    | 20
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92+3
#  lf                          | 90+3
#  cf                          | 90+3
#  rf                          | 90+3
#  rw                          | 92+3
#  lam                         | 92+3
#  cam                         | 92+3
#  ram                         | 92+3
#  lm                          | 90+3
#  lcm                         | 79+3
#  cm                          | 79+3
#  rcm                         | 79+3
#  rm                          | 90+3
#  lwb                         | 62+3
#  ldm                         | 62+3
#  cdm                         | 62+3
#  rdm                         | 62+3
#  rwb                         | 62+3
#  lb                          | 54+3
#  lcb                         | 45+3
#  cb                          | 45+3
#  rcb                         | 45+3
#  rb                          | 54+3
#  gk                          | 15+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  unique_id                   | 0
# -RECORD 1-------------------------------------------
#  sofifa_id                   | 20801
#  player_url                  | https://sofifa.co...
#  short_name                  | Cristiano Ronaldo
#  long_name                   | Cristiano Ronaldo...
#  player_positions            | LW, LM
#  overall                     | 92
#  potential                   | 92
#  value_eur                   | 7.9E7
#  wage_eur                    | 375000.0
#  age                         | 29
#  dob                         | 1985-02-05 00:00:00
#  height_cm                   | 185
#  weight_kg                   | 80
#  club_team_id                | 243.0
#  club_name                   | Real Madrid CF
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | LW
#  club_jersey_number          | 7
#  club_loaned_from            | null
#  club_joined                 | 2009-07-01 00:00:00
#  club_contract_valid_until   | 2018
#  nationality_id              | 38
#  nationality_name            | Portugal
#  nation_team_id              | 1354.0
#  nation_position             | LW
#  nation_jersey_number        | 7
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 5
#  international_reputation    | 5
#  work_rate                   | High/Low
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 93
#  shooting                    | 93
#  passing                     | 81
#  dribbling                   | 91
#  defending                   | 32
#  physic                      | 79
#  attacking_crossing          | 83
#  attacking_finishing         | 95
#  attacking_heading_accuracy  | 86
#  attacking_short_passing     | 82
#  attacking_volleys           | 87
#  skill_dribbling             | 93
#  skill_curve                 | 88
#  skill_fk_accuracy           | 79
#  skill_long_passing          | 72
#  skill_ball_control          | 92
#  movement_acceleration       | 91
#  movement_sprint_speed       | 94
#  movement_agility            | 93
#  movement_reactions          | 90
#  movement_balance            | 63
#  power_shot_power            | 94
#  power_jumping               | 94
#  power_stamina               | 89
#  power_strength              | 79
#  power_long_shots            | 93
#  mentality_aggression        | 63
#  mentality_interceptions     | 24
#  mentality_positioning       | 91
#  mentality_vision            | 81
#  mentality_penalties         | 85
#  mentality_composure         | null
#  defending_marking_awareness | 22
#  defending_standing_tackle   | 31
#  defending_sliding_tackle    | 23
#  goalkeeping_diving          | 7
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 11
#  goalkeeping_speed           | null
#  ls                          | 91+1
#  st                          | 91+1
#  rs                          | 91+1
#  lw                          | 89+3
#  lf                          | 91+1
#  cf                          | 91+1
#  rf                          | 91+1
#  rw                          | 89+3
#  lam                         | 89+3
#  cam                         | 89+3
#  ram                         | 89+3
#  lm                          | 87+3
#  lcm                         | 77+3
#  cm                          | 77+3
#  rcm                         | 77+3
#  rm                          | 87+3
#  lwb                         | 63+3
#  ldm                         | 63+3
#  cdm                         | 63+3
#  rdm                         | 63+3
#  rwb                         | 63+3
#  lb                          | 57+3
#  lcb                         | 52+3
#  cb                          | 52+3
#  rcb                         | 52+3
#  rb                          | 57+3
#  gk                          | 16+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  unique_id                   | 1
# -RECORD 2-------------------------------------------
#  sofifa_id                   | 9014
#  player_url                  | https://sofifa.co...
#  short_name                  | A. Robben
#  long_name                   | Arjen Robben
#  player_positions            | RM, LM, RW
#  overall                     | 90
#  potential                   | 90
#  value_eur                   | 5.45E7
#  wage_eur                    | 275000.0
#  age                         | 30
#  dob                         | 1984-01-23 00:00:00
#  height_cm                   | 180
#  weight_kg                   | 80
#  club_team_id                | 21.0
#  club_name                   | FC Bayern München
#  league_name                 | German 1. Bundesliga
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2009-08-28 00:00:00
#  club_contract_valid_until   | 2017
#  nationality_id              | 34
#  nationality_name            | Netherlands
#  nation_team_id              | 105035.0
#  nation_position             | RS
#  nation_jersey_number        | 11
#  preferred_foot              | Left
#  weak_foot                   | 2
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | High/Low
#  body_type                   | Normal (170-185)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Diver, Injury Pro...
#  pace                        | 93
#  shooting                    | 86
#  passing                     | 83
#  dribbling                   | 92
#  defending                   | 32
#  physic                      | 64
#  attacking_crossing          | 80
#  attacking_finishing         | 85
#  attacking_heading_accuracy  | 50
#  attacking_short_passing     | 86
#  attacking_volleys           | 86
#  skill_dribbling             | 93
#  skill_curve                 | 85
#  skill_fk_accuracy           | 83
#  skill_long_passing          | 76
#  skill_ball_control          | 90
#  movement_acceleration       | 93
#  movement_sprint_speed       | 93
#  movement_agility            | 93
#  movement_reactions          | 89
#  movement_balance            | 91
#  power_shot_power            | 86
#  power_jumping               | 61
#  power_stamina               | 78
#  power_strength              | 65
#  power_long_shots            | 90
#  mentality_aggression        | 47
#  mentality_interceptions     | 39
#  mentality_positioning       | 89
#  mentality_vision            | 84
#  mentality_penalties         | 80
#  mentality_composure         | null
#  defending_marking_awareness | 29
#  defending_standing_tackle   | 26
#  defending_sliding_tackle    | 26
#  goalkeeping_diving          | 10
#  goalkeeping_handling        | 8
#  goalkeeping_kicking         | 11
#  goalkeeping_positioning     | 5
#  goalkeeping_reflexes        | 15
#  goalkeeping_speed           | null
#  ls                          | 84+3
#  st                          | 84+3
#  rs                          | 84+3
#  lw                          | 88+2
#  lf                          | 87+3
#  cf                          | 87+3
#  rf                          | 87+3
#  rw                          | 88+2
#  lam                         | 88+2
#  cam                         | 88+2
#  ram                         | 88+2
#  lm                          | 87+3
#  lcm                         | 78+3
#  cm                          | 78+3
#  rcm                         | 78+3
#  rm                          | 87+3
#  lwb                         | 64+3
#  ldm                         | 64+3
#  cdm                         | 64+3
#  rdm                         | 64+3
#  rwb                         | 64+3
#  lb                          | 55+3
#  lcb                         | 46+3
#  cb                          | 46+3
#  rcb                         | 46+3
#  rb                          | 55+3
#  gk                          | 14+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  unique_id                   | 2
# -RECORD 3-------------------------------------------
#  sofifa_id                   | 41236
#  player_url                  | https://sofifa.co...
#  short_name                  | Z. Ibrahimović
#  long_name                   | Zlatan Ibrahimović
#  player_positions            | ST
#  overall                     | 90
#  potential                   | 90
#  value_eur                   | 5.25E7
#  wage_eur                    | 275000.0
#  age                         | 32
#  dob                         | 1981-10-03 00:00:00
#  height_cm                   | 195
#  weight_kg                   | 95
#  club_team_id                | 73.0
#  club_name                   | Paris Saint-Germain
#  league_name                 | French Ligue 1
#  league_level                | 1
#  club_position               | ST
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2012-07-01 00:00:00
#  club_contract_valid_until   | 2016
#  nationality_id              | 46
#  nationality_name            | Sweden
#  nation_team_id              | 1363.0
#  nation_position             | ST
#  nation_jersey_number        | 10
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Poacher, #Aerial...
#  player_traits               | Power Free-Kick, ...
#  pace                        | 76
#  shooting                    | 91
#  passing                     | 81
#  dribbling                   | 86
#  defending                   | 34
#  physic                      | 86
#  attacking_crossing          | 76
#  attacking_finishing         | 91
#  attacking_heading_accuracy  | 76
#  attacking_short_passing     | 84
#  attacking_volleys           | 92
#  skill_dribbling             | 88
#  skill_curve                 | 80
#  skill_fk_accuracy           | 80
#  skill_long_passing          | 76
#  skill_ball_control          | 90
#  movement_acceleration       | 74
#  movement_sprint_speed       | 77
#  movement_agility            | 86
#  movement_reactions          | 85
#  movement_balance            | 41
#  power_shot_power            | 93
#  power_jumping               | 72
#  power_stamina               | 78
#  power_strength              | 93
#  power_long_shots            | 88
#  mentality_aggression        | 84
#  mentality_interceptions     | 20
#  mentality_positioning       | 86
#  mentality_vision            | 83
#  mentality_penalties         | 91
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 41
#  defending_sliding_tackle    | 27
#  goalkeeping_diving          | 13
#  goalkeeping_handling        | 15
#  goalkeeping_kicking         | 10
#  goalkeeping_positioning     | 9
#  goalkeeping_reflexes        | 12
#  goalkeeping_speed           | null
#  ls                          | 87+3
#  st                          | 87+3
#  rs                          | 87+3
#  lw                          | 84+3
#  lf                          | 86+3
#  cf                          | 86+3
#  rf                          | 86+3
#  rw                          | 84+3
#  lam                         | 86+3
#  cam                         | 86+3
#  ram                         | 86+3
#  lm                          | 83+3
#  lcm                         | 76+3
#  cm                          | 76+3
#  rcm                         | 76+3
#  rm                          | 83+3
#  lwb                         | 61+3
#  ldm                         | 65+3
#  cdm                         | 65+3
#  rdm                         | 65+3
#  rwb                         | 61+3
#  lb                          | 56+3
#  lcb                         | 55+3
#  cb                          | 55+3
#  rcb                         | 55+3
#  rb                          | 56+3
#  gk                          | 17+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  unique_id                   | 3
# -RECORD 4-------------------------------------------
#  sofifa_id                   | 167495
#  player_url                  | https://sofifa.co...
#  short_name                  | M. Neuer
#  long_name                   | Manuel Peter Neuer
#  player_positions            | GK
#  overall                     | 90
#  potential                   | 90
#  value_eur                   | 6.35E7
#  wage_eur                    | 300000.0
#  age                         | 28
#  dob                         | 1986-03-27 00:00:00
#  height_cm                   | 193
#  weight_kg                   | 92
#  club_team_id                | 21.0
#  club_name                   | FC Bayern München
#  league_name                 | German 1. Bundesliga
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 1
#  club_loaned_from            | null
#  club_joined                 | 2011-07-01 00:00:00
#  club_contract_valid_until   | 2019
#  nationality_id              | 21
#  nationality_name            | Germany
#  nation_team_id              | 1337.0
#  nation_position             | GK
#  nation_jersey_number        | 1
#  preferred_foot              | Right
#  weak_foot                   | 4
#  skill_moves                 | 1
#  international_reputation    | 5
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | null
#  player_traits               | GK Up for Corners...
#  pace                        | null
#  shooting                    | null
#  passing                     | null
#  dribbling                   | null
#  defending                   | null
#  physic                      | null
#  attacking_crossing          | 25
#  attacking_finishing         | 25
#  attacking_heading_accuracy  | 25
#  attacking_short_passing     | 42
#  attacking_volleys           | 25
#  skill_dribbling             | 25
#  skill_curve                 | 25
#  skill_fk_accuracy           | 25
#  skill_long_passing          | 41
#  skill_ball_control          | 31
#  movement_acceleration       | 58
#  movement_sprint_speed       | 61
#  movement_agility            | 43
#  movement_reactions          | 89
#  movement_balance            | 35
#  power_shot_power            | 42
#  power_jumping               | 78
#  power_stamina               | 44
#  power_strength              | 83
#  power_long_shots            | 25
#  mentality_aggression        | 29
#  mentality_interceptions     | 30
#  mentality_positioning       | 25
#  mentality_vision            | 20
#  mentality_penalties         | 37
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 25
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 87
#  goalkeeping_handling        | 85
#  goalkeeping_kicking         | 92
#  goalkeeping_positioning     | 90
#  goalkeeping_reflexes        | 86
#  goalkeeping_speed           | 60
#  ls                          | 38+3
#  st                          | 38+3
#  rs                          | 38+3
#  lw                          | 36+3
#  lf                          | 37+3
#  cf                          | 37+3
#  rf                          | 37+3
#  rw                          | 36+3
#  lam                         | 36+3
#  cam                         | 36+3
#  ram                         | 36+3
#  lm                          | 38+3
#  lcm                         | 36+3
#  cm                          | 36+3
#  rcm                         | 36+3
#  rm                          | 38+3
#  lwb                         | 36+3
#  ldm                         | 40+3
#  cdm                         | 40+3
#  rdm                         | 40+3
#  rwb                         | 36+3
#  lb                          | 36+3
#  lcb                         | 38+3
#  cb                          | 38+3
#  rcb                         | 38+3
#  rb                          | 36+3
#  gk                          | 87+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  unique_id                   | 4
# only showing top 5 rows

# %%
playersdf.printSchema()
# Out:
# root
#  |-- sofifa_id: integer (nullable = true)
#  |-- player_url: string (nullable = true)
#  |-- short_name: string (nullable = true)
#  |-- long_name: string (nullable = true)
#  |-- player_positions: string (nullable = true)
#  |-- overall: integer (nullable = true)
#  |-- potential: integer (nullable = true)
#  |-- value_eur: double (nullable = true)
#  |-- wage_eur: double (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- dob: timestamp (nullable = true)
#  |-- height_cm: integer (nullable = true)
#  |-- weight_kg: integer (nullable = true)
#  |-- club_team_id: double (nullable = true)
#  |-- club_name: string (nullable = true)
#  |-- league_name: string (nullable = true)
#  |-- league_level: integer (nullable = true)
#  |-- club_position: string (nullable = true)
#  |-- club_jersey_number: integer (nullable = true)
#  |-- club_loaned_from: string (nullable = true)
#  |-- club_joined: timestamp (nullable = true)
#  |-- club_contract_valid_until: integer (nullable = true)
#  |-- nationality_id: integer (nullable = true)
#  |-- nationality_name: string (nullable = true)
#  |-- nation_team_id: double (nullable = true)
#  |-- nation_position: string (nullable = true)
#  |-- nation_jersey_number: integer (nullable = true)
#  |-- preferred_foot: string (nullable = true)
#  |-- weak_foot: integer (nullable = true)
#  |-- skill_moves: integer (nullable = true)
#  |-- international_reputation: integer (nullable = true)
#  |-- work_rate: string (nullable = true)
#  |-- body_type: string (nullable = true)
#  |-- real_face: string (nullable = true)
#  |-- release_clause_eur: string (nullable = true)
#  |-- player_tags: string (nullable = true)
#  |-- player_traits: string (nullable = true)
#  |-- pace: integer (nullable = true)
#  |-- shooting: integer (nullable = true)
#  |-- passing: integer (nullable = true)
#  |-- dribbling: integer (nullable = true)
#  |-- defending: integer (nullable = true)
#  |-- physic: integer (nullable = true)
#  |-- attacking_crossing: integer (nullable = true)
#  |-- attacking_finishing: integer (nullable = true)
#  |-- attacking_heading_accuracy: integer (nullable = true)
#  |-- attacking_short_passing: integer (nullable = true)
#  |-- attacking_volleys: integer (nullable = true)
#  |-- skill_dribbling: integer (nullable = true)
#  |-- skill_curve: integer (nullable = true)
#  |-- skill_fk_accuracy: integer (nullable = true)
#  |-- skill_long_passing: integer (nullable = true)
#  |-- skill_ball_control: integer (nullable = true)
#  |-- movement_acceleration: integer (nullable = true)
#  |-- movement_sprint_speed: integer (nullable = true)
#  |-- movement_agility: integer (nullable = true)
#  |-- movement_reactions: integer (nullable = true)
#  |-- movement_balance: integer (nullable = true)
#  |-- power_shot_power: integer (nullable = true)
#  |-- power_jumping: integer (nullable = true)
#  |-- power_stamina: integer (nullable = true)
#  |-- power_strength: integer (nullable = true)
#  |-- power_long_shots: integer (nullable = true)
#  |-- mentality_aggression: integer (nullable = true)
#  |-- mentality_interceptions: integer (nullable = true)
#  |-- mentality_positioning: integer (nullable = true)
#  |-- mentality_vision: integer (nullable = true)
#  |-- mentality_penalties: integer (nullable = true)
#  |-- mentality_composure: string (nullable = true)
#  |-- defending_marking_awareness: integer (nullable = true)
#  |-- defending_standing_tackle: integer (nullable = true)
#  |-- defending_sliding_tackle: integer (nullable = true)
#  |-- goalkeeping_diving: integer (nullable = true)
#  |-- goalkeeping_handling: integer (nullable = true)
#  |-- goalkeeping_kicking: integer (nullable = true)
#  |-- goalkeeping_positioning: integer (nullable = true)
#  |-- goalkeeping_reflexes: integer (nullable = true)
#  |-- goalkeeping_speed: integer (nullable = true)
#  |-- ls: string (nullable = true)
#  |-- st: string (nullable = true)
#  |-- rs: string (nullable = true)
#  |-- lw: string (nullable = true)
#  |-- lf: string (nullable = true)
#  |-- cf: string (nullable = true)
#  |-- rf: string (nullable = true)
#  |-- rw: string (nullable = true)
#  |-- lam: string (nullable = true)
#  |-- cam: string (nullable = true)
#  |-- ram: string (nullable = true)
#  |-- lm: string (nullable = true)
#  |-- lcm: string (nullable = true)
#  |-- cm: string (nullable = true)
#  |-- rcm: string (nullable = true)
#  |-- rm: string (nullable = true)
#  |-- lwb: string (nullable = true)
#  |-- ldm: string (nullable = true)
#  |-- cdm: string (nullable = true)
#  |-- rdm: string (nullable = true)
#  |-- rwb: string (nullable = true)
#  |-- lb: string (nullable = true)
#  |-- lcb: string (nullable = true)
#  |-- cb: string (nullable = true)
#  |-- rcb: string (nullable = true)
#  |-- rb: string (nullable = true)
#  |-- gk: string (nullable = true)
#  |-- player_face_url: string (nullable = true)
#  |-- club_logo_url: string (nullable = true)
#  |-- club_flag_url: string (nullable = true)
#  |-- nation_logo_url: string (nullable = true)
#  |-- nation_flag_url: string (nullable = true)
#  |-- year: integer (nullable = false)
#  |-- unique_id: long (nullable = false)

# %%
# Ingest the data from all years (2015-2022) into one Postgres Database table
postgres_url = "jdbc:postgresql://localhost:5432/postgres"
properties = {
    "user": "postgres",
    "password": "V!gnesh5678",
    "driver": "org.postgresql.Driver"
}

table_name = "fifa.fifa_table" 

playersdf.write.jdbc(url=postgres_url, table=table_name, mode="overwrite", properties=properties)

# %% [markdown]
# # End of Task 1

# %% [markdown]
# # Task 2

# %%
from pyspark.sql.functions import col, when, count, avg, desc, dense_rank, rank, row_number
from pyspark.sql.window import Window

# Read data from PostgreSQL
jdbc_url = "jdbc:postgresql://localhost:5432/postgres"
db_properties = {"user": "postgres", "password": "V!gnesh5678", "driver": "org.postgresql.Driver"}
df_fifa = spark.read.jdbc(url=jdbc_url, table="fifa.fifa_table", properties=db_properties)

# %%
df_fifa.show(1, vertical = True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 240272
#  player_url                  | https://sofifa.co...
#  short_name                  | Min Gyeong Min
#  long_name                   | 민경민 闵景民
#  player_positions            | CM
#  overall                     | 51
#  potential                   | 59
#  value_eur                   | 50000.0
#  wage_eur                    | 1000.0
#  age                         | 22
#  dob                         | 1996-06-04 00:00:00
#  height_cm                   | 183
#  weight_kg                   | 65
#  club_team_id                | 2056.0
#  club_name                   | Daegu FC
#  league_name                 | Korean K League 1
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 25
#  club_loaned_from            | null
#  club_joined                 | 2017-07-01 00:00:00
#  club_contract_valid_until   | 2021
#  nationality_id              | 167
#  nationality_name            | Korea Republic
#  nation_team_id              | null
#  nation_position             | null
#  nation_jersey_number        | null
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | 73000
#  player_tags                 | null
#  player_traits               | null
#  pace                        | 66
#  shooting                    | 36
#  passing                     | 49
#  dribbling                   | 50
#  defending                   | 41
#  physic                      | 50
#  attacking_crossing          | 41
#  attacking_finishing         | 31
#  attacking_heading_accuracy  | 46
#  attacking_short_passing     | 59
#  attacking_volleys           | 30
#  skill_dribbling             | 44
#  skill_curve                 | 38
#  skill_fk_accuracy           | 38
#  skill_long_passing          | 50
#  skill_ball_control          | 55
#  movement_acceleration       | 65
#  movement_sprint_speed       | 66
#  movement_agility            | 53
#  movement_reactions          | 49
#  movement_balance            | 67
#  power_shot_power            | 47
#  power_jumping               | 64
#  power_stamina               | 60
#  power_strength              | 43
#  power_long_shots            | 30
#  mentality_aggression        | 53
#  mentality_interceptions     | 41
#  mentality_positioning       | 56
#  mentality_vision            | 46
#  mentality_penalties         | 42
#  mentality_composure         | 43
#  defending_marking_awareness | 41
#  defending_standing_tackle   | 36
#  defending_sliding_tackle    | 49
#  goalkeeping_diving          | 15
#  goalkeeping_handling        | 6
#  goalkeeping_kicking         | 9
#  goalkeeping_positioning     | 8
#  goalkeeping_reflexes        | 12
#  goalkeeping_speed           | null
#  ls                          | 47+1
#  st                          | 47+1
#  rs                          | 47+1
#  lw                          | 49
#  lf                          | 50
#  cf                          | 50
#  rf                          | 50
#  rw                          | 49
#  lam                         | 50+1
#  cam                         | 50+1
#  ram                         | 50+1
#  lm                          | 51+1
#  lcm                         | 50+1
#  cm                          | 50+1
#  rcm                         | 50+1
#  rm                          | 51+1
#  lwb                         | 50+1
#  ldm                         | 48+1
#  cdm                         | 48+1
#  rdm                         | 48+1
#  rwb                         | 50+1
#  lb                          | 49+1
#  lcb                         | 46+1
#  cb                          | 46+1
#  rcb                         | 46+1
#  rb                          | 49+1
#  gk                          | 14+1
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | null
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2019
#  unique_id                   | 137438953472
# only showing top 1 row

# %%
players22df =  df_fifa.filter(df_fifa['year']==2022)
players22_contract23df =  players22df.filter(players22df['club_contract_valid_until']==2023)
grouped_counts = players22_contract23df.groupby('club_name').count()
sorted_counts = grouped_counts.orderBy(desc('count'))

# %% [markdown]
# # X clubs that have the highest number of players with contracts ending in 2023

# %%
X = 10  # Replace X with the desired number of top clubs you want to retrieve
top_X_clubs = sorted_counts.limit(X)

top_X_clubs.show()
# Out:
# +--------------------+-----+
# |           club_name|count|
# +--------------------+-----+
# |En Avant de Guingamp|   19|
# | Club Atlético Lanús|   17|
# |       Lechia Gdańsk|   17|
# |            Barnsley|   16|
# |        Kasimpaşa SK|   16|
# |        Bengaluru FC|   16|
# |        FC Barcelona|   15|
# |  SV Wehen Wiesbaden|   15|
# |          CA Osasuna|   15|
# |      Zagłębie Lubin|   15|
# +--------------------+-----+

# %% [markdown]
# # Y clubs with highest average number of players >27 years of age

# %%
players_above_27 = df_fifa.filter(col('age') > 27)
players_above_27 = players_above_27.filter(col("club_name").isNotNull())

window_spec = Window.partitionBy('club_name')

club_avg_players = players_above_27.groupBy('club_name', 'year') \
    .agg(count('*').alias('player_count'), first('club_name').over(window_spec).alias('club_name_first')) \
    .groupBy('club_name_first') \
    .agg(avg(col('player_count')).alias('avg_players_count'))

# Calculate rank for each club based on the average number of players
club_avg_players_ranked = club_avg_players.withColumn('rank', rank().over(Window.orderBy(col('avg_players_count').desc())))

# Filter the clubs that share the same rank as the Yth club
Y = 10  # Replace with the desired number of clubs
result = club_avg_players_ranked.filter(col('rank') <= Y)

result.show()
# Out:
# +--------------------+-----------------+----+
# |     club_name_first|avg_players_count|rank|
# +--------------------+-----------------+----+
# |  Dorados de Sinaloa|             19.0|   1|
# | Matsumoto Yamaga FC|             19.0|   1|
# | Shanghai Shenhua FC|             18.5|   3|
# |          Qingdao FC|             18.0|   4|
# |Club Deportivo Jo...|             17.5|   5|
# |            Altay SK|             17.0|   6|
# |         Guaireña FC|             17.0|   6|
# |İstanbul Başakşeh...|           16.625|   8|
# |      BB Erzurumspor|             16.5|   9|
# |        Club Olimpia|             16.5|   9|
# |      Sport Huancayo|             16.5|   9|
# +--------------------+-----------------+----+

# %% [markdown]
# # Most frequent Nation Position for each year in dataset

# %%
# Group by 'year' and 'nation_position', count occurrences, and find the most frequent position for each year
most_frequent_nation_positions = df_fifa.groupBy('year', 'nation_position') \
    .agg(count("*").alias("count")) \
    .withColumn("rank", row_number().over(Window.partitionBy("year").orderBy(desc("count")))) \
    .filter(col("rank") == 3) \
    .select("year", "nation_position")

most_frequent_nation_positions.show()
# Out:
# +----+---------------+
# |year|nation_position|
# +----+---------------+
# |2015|            LCB|
# |2016|            RCB|
# |2017|             GK|
# |2018|            LCB|
# |2019|             GK|
# |2020|            RCB|
# |2021|            LCB|
# |2022|            LCB|
# +----+---------------+

# %% [markdown]
# # End of Task 2

# %% [markdown]
# # Task 3

# %%
from pyspark.ml import Pipeline,Transformer
from pyspark.ml.feature import Imputer,StandardScaler,StringIndexer,OneHotEncoder, VectorAssembler

from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np

# %%
col_names = ['sofifa_id', 'player_url', 'short_name', 'long_name', 'player_positions',
 'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name', 'league_name',
 'league_level', 'club_position', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 
 'nationality_id', 'nationality_name', 'nation_team_id', 'nation_position', 'nation_jersey_number', 'preferred_foot',
 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur',
 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration',
 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power',
 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness',
 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling',
 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw',
 'lf', 'cf', 'rf', 'rw','lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb',
 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url',
 'year', 'Unique_ID']

continuous_cols = ['value_eur', 'wage_eur', 'age', 'dob','height_cm','weight_kg','club_team_id','league_level','club_jersey_number',
     'club_contract_valid_until','nationality_id','nation_team_id','nation_jersey_number','weak_foot','skill_moves',
     'international_reputation','pace','shooting','passing','dribbling','defending','physic','attacking_crossing',
     'attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys',
     'skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control',
     'movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power',
     'power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions',
     'mentality_positioning','mentality_vision','mentality_penalties','mentality_composure',
     'defending_marking_awareness','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving',
     'goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes','goalkeeping_speed',
     'year','Unique_ID']

columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'long_name', 'player_positions',
 'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name', 'league_name',
 'league_level', 'club_position', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 
 'nationality_id', 'nationality_name', 'nation_team_id', 'nation_position', 'nation_jersey_number', 'preferred_foot',
 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur',
 'player_tags', 'player_traits','ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw','lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm',
 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 
 'club_flag_url', 'nation_logo_url', 'nation_flag_url', 'year']

# Drop all columns that are not numeric or do not contribute the the "overall" of the player.
df_fifa_dropped = df_fifa.drop(*columns_to_drop)

# %%
null_counts = df_fifa_dropped.select([count(when(col(c).isNull(), c)).alias(c) for c in df_fifa_dropped.columns])

# Show the null counts for each column
null_counts.show(vertical = True)
# Out:
# -RECORD 0-----------------------------
#  overall                     | 0
#  pace                        | 15791
#  shooting                    | 15791
#  passing                     | 15791
#  dribbling                   | 15791
#  defending                   | 15791
#  physic                      | 15791
#  attacking_crossing          | 0
#  attacking_finishing         | 0
#  attacking_heading_accuracy  | 0
#  attacking_short_passing     | 0
#  attacking_volleys           | 0
#  skill_dribbling             | 0
#  skill_curve                 | 0
#  skill_fk_accuracy           | 0
#  skill_long_passing          | 0
#  skill_ball_control          | 0
#  movement_acceleration       | 0
#  movement_sprint_speed       | 0
#  movement_agility            | 0
#  movement_reactions          | 0
#  movement_balance            | 0
#  power_shot_power            | 0
#  power_jumping               | 0
#  power_stamina               | 0
#  power_strength              | 0
#  power_long_shots            | 0
#  mentality_aggression        | 0
#  mentality_interceptions     | 0
#  mentality_positioning       | 0
#  mentality_vision            | 0
#  mentality_penalties         | 0
#  mentality_composure         | 31778
#  defending_marking_awareness | 0
#  defending_standing_tackle   | 0
#  defending_sliding_tackle    | 0
#  goalkeeping_diving          | 0
#  goalkeeping_handling        | 0
#  goalkeeping_kicking         | 0
#  goalkeeping_positioning     | 0
#  goalkeeping_reflexes        | 0
#  goalkeeping_speed           | 126288
#  unique_id                   | 0

# %%
# Drop menatility_composure and goalkeeping_speed columns due to large number of null counts, likely because they were only
# introduces as stats in later versions of the FIFA game.
columns_to_drop = ['mentality_composure', 'goalkeeping_speed']
df_fifa_dropped = df_fifa_dropped.drop(*columns_to_drop)

# Impute these columns, as they most likely relate to GoalKeepers who don't possess these stats.
columns_to_impute = ['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']

# Impute null values with 0 in the specified columns
df_fifa_clean = df_fifa_dropped.fillna(0, subset=columns_to_impute)

null_counts = df_fifa_clean.select([count(when(isnan(c)|col(c).isNull(), c)).alias(c) for c in df_fifa_clean.columns])

# Show the null counts for each column
null_counts.show(vertical = True)
# Out:
# -RECORD 0--------------------------
#  overall                     | 0
#  pace                        | 0
#  shooting                    | 0
#  passing                     | 0
#  dribbling                   | 0
#  defending                   | 0
#  physic                      | 0
#  attacking_crossing          | 0
#  attacking_finishing         | 0
#  attacking_heading_accuracy  | 0
#  attacking_short_passing     | 0
#  attacking_volleys           | 0
#  skill_dribbling             | 0
#  skill_curve                 | 0
#  skill_fk_accuracy           | 0
#  skill_long_passing          | 0
#  skill_ball_control          | 0
#  movement_acceleration       | 0
#  movement_sprint_speed       | 0
#  movement_agility            | 0
#  movement_reactions          | 0
#  movement_balance            | 0
#  power_shot_power            | 0
#  power_jumping               | 0
#  power_stamina               | 0
#  power_strength              | 0
#  power_long_shots            | 0
#  mentality_aggression        | 0
#  mentality_interceptions     | 0
#  mentality_positioning       | 0
#  mentality_vision            | 0
#  mentality_penalties         | 0
#  defending_marking_awareness | 0
#  defending_standing_tackle   | 0
#  defending_sliding_tackle    | 0
#  goalkeeping_diving          | 0
#  goalkeeping_handling        | 0
#  goalkeeping_kicking         | 0
#  goalkeeping_positioning     | 0
#  goalkeeping_reflexes        | 0
#  unique_id                   | 0

# %%
import findspark
findspark.init()
findspark.find()

import pyspark
from pyspark.sql import SparkSession, SQLContext
from pyspark.ml import Pipeline,Transformer
from pyspark.ml.feature import Imputer,StandardScaler,StringIndexer,OneHotEncoder, VectorAssembler

from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np

col_names = [
 'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration',
 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power',
 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'defending_marking_awareness',
 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling',
 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'Unique_ID']

cols_to_drop = ['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration',
 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power',
 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'defending_marking_awareness',
 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling',
 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'Unique_ID']


class OutcomeCreater(Transformer):
    def __init__(self):
        super().__init__()

    def _transform(self, dataset):
        # Use the col() function to create a Column object
        output_df = dataset.withColumn('outcome', col('overall')).drop("overall")
        output_df = output_df.withColumn('outcome', col('outcome').cast(DoubleType()))
        return output_df

class FeatureTypeCaster(Transformer):
    def __init__(self):
        super().__init__()

    def _transform(self, dataset):
        output_df = dataset
        for col_name in cols_to_drop:
            output_df = output_df.withColumn(col_name,col(col_name).cast(DoubleType()))

        return output_df
class ColumnDropper(Transformer): # this transformer drops unnecessary columns
    def __init__(self, columns_to_drop = None):
        super().__init__()
        self.columns_to_drop=columns_to_drop
    def _transform(self, dataset):
        output_df = dataset
        for col_name in self.columns_to_drop:
            output_df = output_df.drop(col_name)
        return output_df 

def get_preprocess_pipeline():
    stage_typecaster = FeatureTypeCaster()
    
    feature_cols = cols_to_drop
    # Maybe we want to drop highly correlated features? 

    stage_vector_assembler = VectorAssembler(inputCols=feature_cols, outputCol="vectorized_features")

    stage_scaler = StandardScaler(inputCol="vectorized_features", outputCol="features")

    stage_outcome = OutcomeCreater()
    
    stage_column_dropper = ColumnDropper(columns_to_drop = cols_to_drop + ['vectorized_features'])

    #pipeline = Pipeline(stages=[stage_outcome, stage_typecaster, stage_vector_assembler, stage_scaler, stage_column_dropper])
    pipeline = Pipeline(stages = [stage_typecaster,stage_vector_assembler,stage_scaler,stage_outcome,stage_column_dropper])
    return pipeline

# %%
preprocess_pipeline = get_preprocess_pipeline()
preprocess_pipeline_model = preprocess_pipeline.fit(df_fifa_clean)

fifadf = preprocess_pipeline_model.transform(df_fifa_clean)

# %%
fifadf.printSchema()
fifadf.show(1, vertical = True)
# Out:
# root
#  |-- features: vector (nullable = true)
#  |-- outcome: double (nullable = true)
#
# -RECORD 0------------------------
#  features | [2.77278744992359...
#  outcome  | 51.0
# only showing top 1 row

# %%
training_data, test_data = fifadf.randomSplit([0.8, 0.2])

# %% [markdown]
# # Spark Version

# %% [markdown]
# # Model 1- Linear Regression

# %% [markdown]
# # Before parameter tuning

# %%
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator

#training_data, test_data = fifadf.randomSplit([0.8, 0.2])

# Define the features column and the target column
features_col = "features"
target_col = "outcome"

# Create a Linear Regression model
lr = LinearRegression(featuresCol=features_col, labelCol=target_col)

# Fit the model to the training data
lr_model = lr.fit(training_data)
predictions = lr_model.transform(test_data)
predictions = predictions.withColumn("rounded_prediction", round(col("prediction")))


# Evaluate the model
evaluator = RegressionEvaluator(labelCol=target_col, predictionCol="rounded_prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data before tuning = {:.2f}".format(rmse))
# Out:
# Root Mean Squared Error (RMSE) on test data before tuning = 2.78

# %%
print("Default Regularization Paramenter: ", lr.getRegParam())
print("Default Maximum Iteration Paramenter: ", lr.getMaxIter())
# Out:
# Default Regularization Paramenter:  0.0
# Default Maximum Iteration Paramenter:  100

# %% [markdown]
# # After parameter Tuning

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

lr = LinearRegression(featuresCol = 'features', labelCol = 'outcome')

# Create ParamGrid for Cross Validation
lr_paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0, 0.01, 0.1, 1])
             .addGrid(lr.maxIter, [100, 500, 1000])
             .build())

evaluator = RegressionEvaluator(predictionCol='prediction', 
    labelCol='outcome', metricName='rmse')

lr_cv = CrossValidator(estimator=lr, estimatorParamMaps=lr_paramGrid, 
                    evaluator=evaluator, numFolds=5)
lr_cv_model = lr_cv.fit(training_data)
lr_cv_prediction_test = lr_cv_model.transform(test_data)

# %%
print("Root Mean Squared Error (RMSE) on test data after tuning = {:.2f}".format(evaluator.evaluate(lr_cv_prediction_test)))

# Access the best model obtained after cross-validation
best_lr_model = lr_cv_model.bestModel

# Access the best parameters from the best model
best_reg_param = best_lr_model.getRegParam()
best_max_iter = best_lr_model.getMaxIter()

print("Regularization Parameter after tuning: ", best_reg_param)
print("Maximum Iteration Parameter after tuning: ", best_max_iter)
# Out:
# Root Mean Squared Error (RMSE) on test data after tuning = 2.77
# Regularization Parameter after tuning:  0.0
# Maximum Iteration Parameter after tuning:  100

# %%
predictions = best_lr_model.transform(test_data)
predictions = predictions.withColumn("rounded_prediction", round(col("prediction")))
predictions.show(5)
# Out:
# +--------------------+-------+-----------------+------------------+
# |            features|outcome|       prediction|rounded_prediction|
# +--------------------+-------+-----------------+------------------+
# |[0.0,0.0,0.0,0.0,...|   71.0|66.28407303483388|              66.0|
# |[0.0,0.0,0.0,0.0,...|   71.0|67.23984093782397|              67.0|
# |[0.0,0.0,0.0,0.0,...|   58.0|56.69213462445589|              57.0|
# |[0.0,0.0,0.0,0.0,...|   54.0|54.71469278475102|              55.0|
# |[0.0,0.0,0.0,0.0,...|   62.0|63.65400039164052|              64.0|
# +--------------------+-------+-----------------+------------------+
# only showing top 5 rows

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter( predictions.select('outcome').collect(), predictions.select('rounded_prediction').collect(), alpha=0.5)
plt.title('Linear Regression: Predicted vs Actual')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.show()
# Out:
# Exception ignored in: <function JavaWrapper.__del__ at 0x000001E375461040>
# Traceback (most recent call last):
#   File "C:\SPARK\spark-3.3.3-bin-hadoop3\python\pyspark\ml\wrapper.py", line 53, in __del__
#     if SparkContext._active_spark_context and self._java_obj is not None:
# AttributeError: 'RegressionEvaluator' object has no attribute '_java_obj'

# %% [markdown]
# # Model 2 - Gradient Boosted Tree Regression

# %% [markdown]
# # Before Parameter Tuning

# %%
from pyspark.ml.regression import GBTRegressor

gbt = GBTRegressor(featuresCol=features_col, labelCol=target_col)
gbt_model = gbt.fit(training_data)
predictions_gbt = gbt_model.transform(test_data)
predictions_gbt = predictions_gbt.withColumn("rounded_prediction", round(col("prediction")))

evaluator_gbt = RegressionEvaluator(labelCol=target_col, predictionCol="rounded_prediction", metricName="rmse")
rmse_gbt = evaluator_gbt.evaluate(predictions_gbt)
print("GBT RMSE on test data before tuning = {:.2f}".format(rmse_gbt))
# Out:
# GBT RMSE on test data before tuning = 1.92

# %%
print("Default Step Size/Learning Rate Parameter: ", gbt.getStepSize())
print("Default Maximum Depth Paramenter: ", gbt.getMaxDepth())
# Out:
# Default Step Size/Learning Rate Parameter:  0.1
# Default Maximum Depth Paramenter:  5

# %% [markdown]
# # After Parameter Tuning

# %%
gbt = GBTRegressor(featuresCol = 'features', labelCol = 'outcome')

# Create ParamGrid for Cross Validation
gbt_paramGrid = (ParamGridBuilder()
             .addGrid(gbt.stepSize, [0.001, 0.01, 0.1, 0.5])
             .addGrid(gbt.maxDepth, [2, 5, 10])
             .build())

evaluator = RegressionEvaluator(predictionCol='prediction', 
    labelCol='outcome', metricName='rmse')

gbt_cv = CrossValidator(estimator=gbt, estimatorParamMaps=gbt_paramGrid, 
                    evaluator=evaluator, numFolds=5)
gbt_cv_model = gbt_cv.fit(training_data)
gbt_cv_prediction_test = gbt_cv_model.transform(test_data)

# %%
print("Root Mean Squared Error (RMSE) on test data after tuning = {:.2f}".format(evaluator.evaluate(gbt_cv_prediction_test)))

# Access the best model obtained after cross-validation
best_gbt_model = gbt_cv_model.bestModel

# Access the best parameters from the best model
best_step_size = best_gbt_model.getStepSize()
best_max_depth = best_gbt_model.getMaxDepth()

print("Step Size/Learning Rate Parameter after tuning: ", best_step_size)
print("Maximum Depth Parameter after tuning: ", best_max_depth)
# Out:
# Root Mean Squared Error (RMSE) on test data after tuning = 1.38
# Step Size/Learning Rate Parameter after tuning:  0.1
# Maximum Depth Parameter after tuning:  10

# %%
predictions = best_gbt_model.transform(test_data)
predictions = predictions.withColumn("rounded_prediction", round(col("prediction")))
predictions.show(5)
# Out:
# +--------------------+-------+------------------+------------------+
# |            features|outcome|        prediction|rounded_prediction|
# +--------------------+-------+------------------+------------------+
# |[0.0,0.0,0.0,0.0,...|   71.0| 70.97842965832238|              71.0|
# |[0.0,0.0,0.0,0.0,...|   71.0| 70.89948892684117|              71.0|
# |[0.0,0.0,0.0,0.0,...|   58.0|58.594642479603195|              59.0|
# |[0.0,0.0,0.0,0.0,...|   54.0|53.294127839251665|              53.0|
# |[0.0,0.0,0.0,0.0,...|   62.0| 62.45802718186232|              62.0|
# +--------------------+-------+------------------+------------------+
# only showing top 5 rows

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(predictions.select('outcome').collect(), predictions.select('rounded_prediction').collect(), alpha=0.5)
plt.title('Gradient-Boosted Tree Regression: Predicted vs Actual')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.show()

# %% [markdown]
# # PyTorch Version

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch  # now import the pytorch module
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt

validation_data, test_data = test_data.randomSplit([0.5, 0.5])

dffifa_pandas = training_data.toPandas()
dffifa_validation_pandas = validation_data.toPandas()
dfffifa_test_pandas = test_data.toPandas()

x_train = torch.from_numpy(np.array(dffifa_pandas['features'].values.tolist(),np.float32))
y_train = torch.from_numpy(np.array(dffifa_pandas['outcome'].values.tolist(), np.float32))
x_val = torch.from_numpy(np.array(dffifa_validation_pandas['features'].values.tolist(),np.float32))
y_val = torch.from_numpy(np.array(dffifa_validation_pandas['outcome'].values.tolist(), np.float32))
x_test = torch.from_numpy(np.array(dfffifa_test_pandas['features'].values.tolist(),np.float32))
y_test = torch.from_numpy(np.array(dfffifa_test_pandas['outcome'].values.tolist(), np.float32))

# %%
from torch.utils.data import Dataset
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __len__(self):
        return self.x.shape[0]
    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])

# %%
train_dataset = MyDataset(x_train, y_train)
validate_dataset = MyDataset(x_val, y_val)
test_dataset = MyDataset(x_test, y_test)

print("Train: ", len(train_dataset))
print("Test: ",len(test_dataset))
print("Validate: ",len(validate_dataset))
# Out:
# Train:  113555
# Test:  14234
# Validate:  14290

# %% [markdown]
# # Neural Network Model 1; 2 hidden layer width of 8

# %%
class Neural_Network(nn.Module):
    def __init__(self,input_dim,output_dim):
        super().__init__()
        self.sequential = nn.Sequential(  # here we stack multiple layers together
            nn.Linear(input_dim,8),
            nn.ReLU(),
            nn.Linear(8,8),
            nn.ReLU(),
            nn.Linear(8,output_dim)
        )
    def forward(self,x):
        y = self.sequential(x)
        return y
mymodel = Neural_Network(x_train.shape[1],1)
print(mymodel)
# Out:
# Neural_Network(
#   (sequential): Sequential(
#     (0): Linear(in_features=40, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=8, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=8, out_features=1, bias=True)
#   )
# )

# %%
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt


lr = 0.01
batch_size = 64
N_epochs = 50

loss_fun = nn.MSELoss()

train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
validation_dataloader = DataLoader(validate_dataset, batch_size = batch_size, shuffle = True)

optimizer = torch.optim.Adam(mymodel.parameters(), lr=lr)

train_losses = []
train_accuracies = []
validation_losses =[]
validation_accuracies =[]
train_batch_loss_overall = []

current_best_validation_loss = 100

for epoch in range(N_epochs):
    train_batch_loss = []
    for x_batch, y_batch in train_dataloader:
        mymodel.train()
        prediction_score = mymodel(x_batch).squeeze()
        loss = loss_fun(prediction_score, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_batch_loss.append(loss.detach().numpy())
        train_batch_loss_overall.append(loss.detach().numpy())
    
    validation_batch_loss = []
    for x_batch, y_batch in validation_dataloader:
        mymodel.eval()
        prediction_score = mymodel(x_batch).squeeze()
        loss = loss_fun(prediction_score, y_batch)
        validation_batch_loss.append(loss.detach())
        
    train_losses.append(np.mean(np.array(train_batch_loss)))
    validation_losses.append(np.mean(np.array(validation_batch_loss)))
    
    print(f"Epoch = {epoch}, train_loss= {train_losses[-1]}, validation_loss= {validation_losses[-1]}")
    
    if validation_losses[-1]<current_best_validation_loss:
        print("Current epoch is best so far. Saving model...")
        torch.save(mymodel.state_dict(), 'current_best_model')
        current_best_validation_loss = validation_losses[-1]
        
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (12,8))
axes[0].plot(range(N_epochs), train_losses, label = 'Train Loss')
axes[0].plot(range(N_epochs), validation_losses, label = 'Validation Loss')
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

axes[1].plot(range(len(train_batch_loss_overall)), train_batch_loss_overall, label = 'Train Loss per batch')
axes[1].set_xlabel("Iterations")
axes[1].set_ylabel("Train Batch Loss")
plt.tight_layout()
# Out:
# Epoch = 0, train_loss= 54.4366340637207, validation_loss= 8.51828670501709
# Current epoch is best so far. Saving model...
# Epoch = 1, train_loss= 8.41546630859375, validation_loss= 8.436905860900879
# Current epoch is best so far. Saving model...
# Epoch = 2, train_loss= 8.425558090209961, validation_loss= 9.009688377380371
# Epoch = 3, train_loss= 8.406530380249023, validation_loss= 8.645577430725098
# Epoch = 4, train_loss= 6.853942394256592, validation_loss= 4.5326828956604
# Current epoch is best so far. Saving model...
# Epoch = 5, train_loss= 3.936357259750366, validation_loss= 3.512838125228882
# Current epoch is best so far. Saving model...
# Epoch = 6, train_loss= 3.5165586471557617, validation_loss= 3.3321571350097656
# Current epoch is best so far. Saving model...
# Epoch = 7, train_loss= 3.430175304412842, validation_loss= 3.368833541870117
# Epoch = 8, train_loss= 3.4011316299438477, validation_loss= 3.008687734603882
# Current epoch is best so far. Saving model...
# Epoch = 9, train_loss= 3.3433165550231934, validation_loss= 4.769786357879639
# Epoch = 10, train_loss= 3.3048059940338135, validation_loss= 3.6978166103363037
# Epoch = 11, train_loss= 3.3758087158203125, validation_loss= 5.6806511878967285
# Epoch = 12, train_loss= 3.095996856689453, validation_loss= 2.757185697555542
# Current epoch is best so far. Saving model...
# Epoch = 13, train_loss= 2.7942490577697754, validation_loss= 2.5944511890411377
# Current epoch is best so far. Saving model...
# Epoch = 14, train_loss= 2.6633920669555664, validation_loss= 2.4581196308135986
# Current epoch is best so far. Saving model...
# Epoch = 15, train_loss= 2.6749603748321533, validation_loss= 2.753525972366333
# Epoch = 16, train_loss= 2.5616462230682373, validation_loss= 2.30415678024292
# Current epoch is best so far. Saving model...
# Epoch = 17, train_loss= 2.466460943222046, validation_loss= 2.1303274631500244
# Current epoch is best so far. Saving model...
# Epoch = 18, train_loss= 2.255866527557373, validation_loss= 1.9469830989837646
# Current epoch is best so far. Saving model...
# Epoch = 19, train_loss= 2.107171058654785, validation_loss= 1.8150346279144287
# Current epoch is best so far. Saving model...
# Epoch = 20, train_loss= 2.0504348278045654, validation_loss= 1.9392844438552856
# Epoch = 21, train_loss= 1.9942795038223267, validation_loss= 1.7424687147140503
# Current epoch is best so far. Saving model...
# Epoch = 22, train_loss= 1.9878848791122437, validation_loss= 2.7882895469665527
# Epoch = 23, train_loss= 1.9806910753250122, validation_loss= 2.16758394241333
# Epoch = 24, train_loss= 1.9594545364379883, validation_loss= 1.8760672807693481
# Epoch = 25, train_loss= 1.986308217048645, validation_loss= 1.7986068725585938
# Epoch = 26, train_loss= 1.9394681453704834, validation_loss= 1.762609839439392
# Epoch = 27, train_loss= 1.9323638677597046, validation_loss= 1.964891791343689
# Epoch = 28, train_loss= 1.9245086908340454, validation_loss= 1.77289879322052
# Epoch = 29, train_loss= 1.932158350944519, validation_loss= 1.8160936832427979
# Epoch = 30, train_loss= 1.9338809251785278, validation_loss= 1.7284780740737915
# Current epoch is best so far. Saving model...
# Epoch = 31, train_loss= 1.9181618690490723, validation_loss= 1.8596774339675903
# Epoch = 32, train_loss= 1.9117233753204346, validation_loss= 2.1730103492736816
# Epoch = 33, train_loss= 1.926291584968567, validation_loss= 1.7575817108154297
# Epoch = 34, train_loss= 1.9074807167053223, validation_loss= 1.817068099975586
# Epoch = 35, train_loss= 1.8828758001327515, validation_loss= 1.9820188283920288
# Epoch = 36, train_loss= 1.9214348793029785, validation_loss= 1.782063364982605
# Epoch = 37, train_loss= 1.8930950164794922, validation_loss= 1.700500726699829
# Current epoch is best so far. Saving model...
# Epoch = 38, train_loss= 1.8623580932617188, validation_loss= 1.731796145439148
# Epoch = 39, train_loss= 1.8787301778793335, validation_loss= 2.75040864944458
# Epoch = 40, train_loss= 1.9057400226593018, validation_loss= 1.7854455709457397
# Epoch = 41, train_loss= 1.8797141313552856, validation_loss= 1.7024651765823364
# Epoch = 42, train_loss= 1.8811976909637451, validation_loss= 1.792052984237671
# Epoch = 43, train_loss= 1.8766193389892578, validation_loss= 1.7742453813552856
# Epoch = 44, train_loss= 1.8776881694793701, validation_loss= 1.9224046468734741
# Epoch = 45, train_loss= 1.8731236457824707, validation_loss= 2.490039825439453
# Epoch = 46, train_loss= 1.8828214406967163, validation_loss= 1.7829296588897705
# Epoch = 47, train_loss= 1.8799034357070923, validation_loss= 1.7005300521850586
# Epoch = 48, train_loss= 1.8720964193344116, validation_loss= 1.83283531665802
# Epoch = 49, train_loss= 1.854444980621338, validation_loss= 1.7398706674575806

# %%
bestmodel = Neural_Network(x_train.shape[1], 1)
bestmodel.load_state_dict(torch.load("current_best_model"))
prediction_score = bestmodel(x_test).squeeze()
        
squared_diff = (prediction_score - y_test)**2

# Step 2: Compute the mean of squared differences
mean_squared_diff = squared_diff.mean()

# Step 3: Take the square root to get RMSE
rmse = torch.sqrt(mean_squared_diff).detach().numpy()
print(f"Test RMSE = {rmse:.2f}")
# Out:
# Test RMSE = 1.30

# %% [markdown]
# # Neural Network Model 2; 6 hidden layers width of 16, 32, 64, 64, 32, 16

# %%
class Neural_Network_Deep(nn.Module):
    def __init__(self,input_dim,output_dim):
        super().__init__()
        self.sequential = nn.Sequential(  # here we stack multiple layers together
            nn.Linear(input_dim,16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32,64),
            nn.ReLU(),
            nn.Linear(64,64),
            nn.ReLU(),
            nn.Linear(64,32),
            nn.ReLU(),
            nn.Linear(32,16),
            nn.ReLU(),
            nn.Linear(16,output_dim)
        )
    def forward(self,x):
        y = self.sequential(x)
        return y
mymodel = Neural_Network_Deep(x_train.shape[1],1)
print(mymodel)
# Out:
# Neural_Network_Deep(
#   (sequential): Sequential(
#     (0): Linear(in_features=40, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=64, out_features=32, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=32, out_features=16, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt


lr = 0.01
batch_size = 64
N_epochs = 50

loss_fun = nn.MSELoss()

train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
validation_dataloader = DataLoader(validate_dataset, batch_size = batch_size, shuffle = True)

optimizer = torch.optim.Adam(mymodel.parameters(), lr=lr)

train_losses = []
train_accuracies = []
validation_losses =[]
validation_accuracies =[]
train_batch_loss_overall = []

current_best_validation_loss = 100

for epoch in range(N_epochs):
    train_batch_loss = []
    for x_batch, y_batch in train_dataloader:
        mymodel.train()
        prediction_score = mymodel(x_batch).squeeze()
        loss = loss_fun(prediction_score, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_batch_loss.append(loss.detach().numpy())
        train_batch_loss_overall.append(loss.detach().numpy())
    
    validation_batch_loss = []
    for x_batch, y_batch in validation_dataloader:
        mymodel.eval()
        prediction_score = mymodel(x_batch).squeeze()
        loss = loss_fun(prediction_score, y_batch)
        validation_batch_loss.append(loss.detach())
        
    train_losses.append(np.mean(np.array(train_batch_loss)))
    validation_losses.append(np.mean(np.array(validation_batch_loss)))
    
    print(f"Epoch = {epoch}, train_loss= {train_losses[-1]}, validation_loss= {validation_losses[-1]}")
    
    if validation_losses[-1]<current_best_validation_loss:
        print("Current epoch is best so far. Saving model...")
        torch.save(mymodel.state_dict(), 'current_best_model')
        current_best_validation_loss = validation_losses[-1]
        
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (12,8))
axes[0].plot(range(N_epochs), train_losses, label = 'Train Loss')
axes[0].plot(range(N_epochs), validation_losses, label = 'Validation Loss')
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

axes[1].plot(range(len(train_batch_loss_overall)), train_batch_loss_overall, label = 'Train Loss per Batch')
axes[1].set_xlabel("Iterations")
axes[1].set_ylabel("Train Batch Loss")
plt.tight_layout()
# Out:
# Epoch = 0, train_loss= 1.2301971912384033, validation_loss= 1.2082369327545166
# Current epoch is best so far. Saving model...
# Epoch = 1, train_loss= 1.1077075004577637, validation_loss= 0.9187121987342834
# Current epoch is best so far. Saving model...
# Epoch = 2, train_loss= 1.1203203201293945, validation_loss= 1.7944399118423462
# Epoch = 3, train_loss= 1.1327956914901733, validation_loss= 0.9719799757003784
# Epoch = 4, train_loss= 1.0990792512893677, validation_loss= 0.8731476664543152
# Current epoch is best so far. Saving model...
# Epoch = 5, train_loss= 1.1029692888259888, validation_loss= 0.8634973764419556
# Current epoch is best so far. Saving model...
# Epoch = 6, train_loss= 1.0848294496536255, validation_loss= 1.0105160474777222
# Epoch = 7, train_loss= 1.0738279819488525, validation_loss= 1.381317138671875
# Epoch = 8, train_loss= 1.0801481008529663, validation_loss= 0.9045010805130005
# Epoch = 9, train_loss= 1.0964593887329102, validation_loss= 1.1686136722564697
# Epoch = 10, train_loss= 1.06488037109375, validation_loss= 0.9016340374946594
# Epoch = 11, train_loss= 1.0846240520477295, validation_loss= 1.0934380292892456
# Epoch = 12, train_loss= 1.0638744831085205, validation_loss= 1.067415475845337
# Epoch = 13, train_loss= 1.0649405717849731, validation_loss= 0.9492183327674866
# Epoch = 14, train_loss= 1.0649291276931763, validation_loss= 0.9088100790977478
# Epoch = 15, train_loss= 1.0546287298202515, validation_loss= 0.9183356165885925
# Epoch = 16, train_loss= 1.0694358348846436, validation_loss= 1.1452581882476807
# Epoch = 17, train_loss= 1.068169116973877, validation_loss= 1.1503573656082153
# Epoch = 18, train_loss= 1.067616581916809, validation_loss= 1.688750982284546
# Epoch = 19, train_loss= 1.0594710111618042, validation_loss= 1.4017927646636963
# Epoch = 20, train_loss= 1.0604240894317627, validation_loss= 1.4313536882400513
# Epoch = 21, train_loss= 1.0701415538787842, validation_loss= 2.0686566829681396
# Epoch = 22, train_loss= 1.036807894706726, validation_loss= 0.9399817585945129
# Epoch = 23, train_loss= 1.0519016981124878, validation_loss= 0.9286261796951294
# Epoch = 24, train_loss= 1.075323224067688, validation_loss= 1.236262559890747
# Epoch = 25, train_loss= 1.0483133792877197, validation_loss= 0.9639390110969543
# Epoch = 26, train_loss= 1.0391358137130737, validation_loss= 0.8679167628288269
# Epoch = 27, train_loss= 1.012983798980713, validation_loss= 1.4801692962646484
# Epoch = 28, train_loss= 1.0557053089141846, validation_loss= 0.918406069278717
# Epoch = 29, train_loss= 1.0143946409225464, validation_loss= 0.8528409600257874
# Current epoch is best so far. Saving model...
# Epoch = 30, train_loss= 1.0125294923782349, validation_loss= 0.8237100839614868
# Current epoch is best so far. Saving model...
# Epoch = 31, train_loss= 1.0542100667953491, validation_loss= 1.0415464639663696
# Epoch = 32, train_loss= 1.008490800857544, validation_loss= 0.8137059211730957
# Current epoch is best so far. Saving model...
# Epoch = 33, train_loss= 1.0227501392364502, validation_loss= 0.8054136037826538
# Current epoch is best so far. Saving model...
# Epoch = 34, train_loss= 0.9945862889289856, validation_loss= 0.8284631371498108
# Epoch = 35, train_loss= 0.9879856109619141, validation_loss= 0.9641873240470886
# Epoch = 36, train_loss= 0.978708803653717, validation_loss= 0.8706352114677429
# Epoch = 37, train_loss= 0.9797902703285217, validation_loss= 0.8345805406570435
# Epoch = 38, train_loss= 0.9472063183784485, validation_loss= 1.064172625541687
# Epoch = 39, train_loss= 0.9518108367919922, validation_loss= 1.142146348953247
# Epoch = 40, train_loss= 0.9458580613136292, validation_loss= 0.7995586395263672
# Current epoch is best so far. Saving model...
# Epoch = 41, train_loss= 0.9301468133926392, validation_loss= 1.0728161334991455
# Epoch = 42, train_loss= 0.9486629962921143, validation_loss= 0.9208088517189026
# Epoch = 43, train_loss= 0.9621005058288574, validation_loss= 0.9277462363243103
# Epoch = 44, train_loss= 0.9476416707038879, validation_loss= 1.2059862613677979
# Epoch = 45, train_loss= 0.9350720643997192, validation_loss= 1.208760142326355
# Epoch = 46, train_loss= 0.9369103908538818, validation_loss= 1.020053505897522
# Epoch = 47, train_loss= 0.9352412819862366, validation_loss= 0.7536258697509766
# Current epoch is best so far. Saving model...
# Epoch = 48, train_loss= 0.9304801821708679, validation_loss= 0.7600951790809631
# Epoch = 49, train_loss= 0.9160703420639038, validation_loss= 0.8982165455818176

# %%
bestmodel = Neural_Network_Deep(x_train.shape[1], 1)
bestmodel.load_state_dict(torch.load("current_best_model"))
prediction_score = bestmodel(x_test).squeeze()
        
squared_diff = (prediction_score - y_test)**2

# Step 2: Compute the mean of squared differences
mean_squared_diff = squared_diff.mean()

# Step 3: Take the square root to get RMSE
rmse = torch.sqrt(mean_squared_diff).detach().numpy()
print(f"Test RMSE = {rmse:.2f}")
# Out:
# Test RMSE = 0.86

# %%
rounded_predicted_values = torch.round(prediction_score)

# Display column names
print("{:<15} {:<15}".format('True Value', 'Predicted Value'))

# Display rows (only the first 5 rows)
for true_val, pred_val in zip(y_test[:5], rounded_predicted_values[:5]):
    print("{:<15} {:<15}".format(true_val.item(), pred_val.item()))
# Out:
# True Value      Predicted Value
# 54.0            54.0
# 68.0            68.0
# 73.0            72.0
# 67.0            67.0
# 74.0            74.0
